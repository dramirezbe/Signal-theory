# %% [markdown]
# ## Hecho por: David Ramírez Betancourth
# ## C.C. 1002636667
# ## Ingeniería Electrónica
# ## Universidad Nacional de Colombia Sede Manizales

# %%
import matplotlib.pyplot as plt #Graficador
import numpy as np #Opearciones entre arrays
import scipy.signal as sig #métodos de señales (welch)
import scipy.stats as stats
import time
import timeit


import tensorflow as tf # Red Neuronal
from sklearn.model_selection import train_test_split #Divisor de datos de entrenamiento y testeo
from sklearn.preprocessing import MinMaxScaler #Normalizador de escala
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.models import Sequential #Red Neuronal
from tensorflow.keras.layers import Dense, Dropout, LSTM #Conexión neuronas
from tensorflow.keras.optimizers import Adam #Optimizador de red

# %% [markdown]
# #Generar Señal
#
# $f_o = 1 Hz$
#
# $x(t) = cos(\omega_o) - \frac{sin(3\omega_o)}{3} + \frac{cos(5\omega_o)}{5}$
#
# $\xi(t) = x(t) + \eta(t)$
#
# Aplicar método welch: Consiste en hallar la FFT por ventaneos de la señal y luego promediando las PSD de cada segmento

# %%
np.random.seed(0)

def randomvector(sigma, N):
    """Genera un vector gaussiano eta = N(0, sigma)"""
    return np.random.normal(0, np.sqrt(sigma), size=N)

def real_signal(t, wo):
    """x(t)"""
    return np.cos(wo*t) - (1/3)*np.sin(3*wo*t) + (1/5)*np.cos(5*wo*t)

def welch_vector(X, fs, nperseg, window, nfft):
    """Generar psd de la señal xi
       ventaneo hamming
       overlap del 50% de la vetana
    """
    return sig.welch(X, fs, window=window, nperseg=nperseg, noverlap=(nperseg//2), nfft=nfft)

def matrix_data(t, wo, sigma, N, M):
    N = len(t)
    X = np.zeros((M, N))  # Ajustar la dimensión de la matriz
    for i in range(M):
        X_true = real_signal(t, wo)  # Generar señal real
        X[i] = X_true + randomvector(sigma, N)  # Combinarla con ruido, meterla a la fila
    return X

def matrix_psd(X, fs, nperseg, window, nfft, fn, N, M):

    Psd_real = np.zeros((M, N))  # Matriz para almacenar los PSD
    for i in range(M):
        f, psd = welch_vector(X[i], fs, nperseg, window, nfft)
        Psd_real[i] = psd
    
    return f[:fn], Psd_real[:, :fn]


def matrix_psd_mean(X, fs, nperseg, window, nfft, fn, N, M):

    f, psd_m = matrix_psd(X, fs, nperseg, window, nfft, fn, N, M)
    
    Psd_mean = np.mean(psd_m, axis=0)
    Psd_mean_m =np.zeros((M, fn))
    for i in range(M):
        Psd_mean_m[i] = Psd_mean

    return f, Psd_mean_m

# Parámetros
N = 1024  # Longitud señal
M = 1000  # Número de señales
fo = 10  # 10Hz frecuencia
wo = 2*np.pi*fo
sigma = 0.1  # Varianza
t = np.linspace(0, 1, N)  # Vector de tiempo de 0 a 3 segundos
fs = 1/(t[1]-t[0])  # Frecuencia de muestreo
nperseg = N - 1
nfft = N*2 - 1
fn = int(5*fo) + 100

# Generación de datos
X = matrix_data(t, wo, sigma, N, M)

# Cálculo de PSD para cada señal
f, Psd_real = matrix_psd(X, fs, nperseg, 'blackmanharris', nfft, fn, N, M)
f, Psd_mean = matrix_psd_mean(X, fs, nperseg, 'blackmanharris', nfft, fn, N, M)

# %% [markdown]
# # Definir tipo de Red
#
# ## Red #1 (MLP)
#
# Modelo tipo Sequential(MLP): Las capas se apilan una tras otra, lo que hace que el flujo de datos sea simple y directo. Es MLP porque contiene perceptrones. Capa de entrada - capa oculta - capa de salida. Configuración Dense.
#
# Optimizador Adam: Utiliza AdaGrad y RMSProp. Consiste en:
# - Calcular Gradiente
# - Se corrige sesgos
# - Se actualizan pesos
# - Red #2 = LSTM
#
# # Preparar Datos
#
# Scaler: normaliza los datos a una escala deseada (0,1)
#
# train test split: Divide los datos un porcentaje deseado 70/30, 70 entrenar, 30 test.

# %%
def data_split_scaled(X , Psd, test_size):
    scalerX = MinMaxScaler(feature_range=(0, 1))
    scalerPsd = MinMaxScaler(feature_range=(0, 1))

    X_scaled = scalerX.fit_transform(X)
    Psd_scaled = scalerPsd.fit_transform(Psd)

    X_train, X_test, y_train, y_test = train_test_split(X_scaled, Psd_scaled, test_size=test_size, random_state=42)

    return X_train, X_test, y_train, y_test, X_scaled, Psd_scaled, scalerX, scalerPsd


def NN_define(type, X_train, y_train, epochs, N, fn):
    input_shape = N
    output_shape = fn

    if type == 1:
        model = Sequential([
            tf.keras.Input(shape=(input_shape,)), #Capa de entrada
            Dense(input_shape//2, activation='relu'), #Capa oculta
            Dropout(0.5), #Dropout para no sobreajuste
            Dense(input_shape//4, activation='relu'), # Capa oculta
            Dense(128, activation='relu'), #Capa oculta
            Dense(output_shape) #Capa de salida
        ])
        
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['accuracy'])

    else:
        model = Sequential()

        model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
        model.add(LSTM(units=50, return_sequences=False))
        model.add(Dense(units=y_train.shape[1]))

        model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['accuracy'])

    return model.fit(X_train, y_train, epochs=epochs, validation_split=0.2), model

# %%
X_train, X_test, y_train, y_test, X_scaled, Psd_scaled, scalerX, scalerPsd= data_split_scaled(X, Psd_real, 0.3)
X_train_mean, X_test_mean, y_train_mean, y_test_mean, X_scaled_mean, Psd_scaled_mean, scalerX_mean, scalerPsd_mean= data_split_scaled(X, Psd_mean, 0.3) 

X_train_reshaped = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_reshaped = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

def train_model():
    history1, model1 = NN_define(1, X_train, y_train, 30, N, fn)
    return history1, model1

# Usar timeit para medir el tiempo de entrenamiento
execution_time = timeit.timeit(train_model, number=1)
print(f"Tiempo de entrenamiento: {execution_time:.2f} segundos")
history1, model1 = train_model()




#history2, model2 = NN_define(1, X_train_mean, y_train_mean, 30, N, fn)
#history3, model3 = NN_define(2, X_train_reshaped, y_train, 5, N, fn)
# Out:
# Epoch 1/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.0138 - loss: 0.1470 - val_accuracy: 0.0143 - val_loss: 0.0606
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0170 - loss: 0.0654 - val_accuracy: 0.0214 - val_loss: 0.0542
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0228 - loss: 0.0564 - val_accuracy: 0.0071 - val_loss: 0.0484
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0183 - loss: 0.0501 - val_accuracy: 0.0500 - val_loss: 0.0426
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0249 - loss: 0.0443 - val_accuracy: 0.0357 - val_loss: 0.0371
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0260 - loss: 0.0390 - val_accuracy: 0.0357 - val_loss: 0.0322
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0373 - loss: 0.0338 - val_accuracy: 0.0286 - val_loss: 0.0282
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0204 - loss: 0.0307 - val_accuracy: 0.0357 - val_loss: 0.0257
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0357 - loss: 0.0273 - val_accuracy: 0.0500 - val_loss: 0.0239
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0455 - loss: 0.0250 - val_accuracy: 0.0643 - val_loss: 0.0225
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0453 - loss: 0.0243 - val_accuracy: 0.0571 - val_loss: 0.0222
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0669 - loss: 0.0236 - val_accuracy: 0.0357 - val_loss: 0.0214
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0363 - loss: 0.0223 - val_accuracy: 0.0643 - val_loss: 0.0210
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0383 - loss: 0.0222 - val_accuracy: 0.0643 - val_loss: 0.0208
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0346 - loss: 0.0223 - val_accuracy: 0.0429 - val_loss: 0.0209
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0431 - loss: 0.0215 - val_accuracy: 0.0643 - val_loss: 0.0210
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0338 - loss: 0.0222 - val_accuracy: 0.0571 - val_loss: 0.0205
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0718 - loss: 0.0210 - val_accuracy: 0.0786 - val_loss: 0.0206
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0440 - loss: 0.0213 - val_accuracy: 0.0714 - val_loss: 0.0209
# Epoch 20/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0594 - loss: 0.0216 - val_accuracy: 0.0714 - val_loss: 0.0203
# Epoch 21/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0443 - loss: 0.0210 - val_accuracy: 0.0857 - val_loss: 0.0203
# Epoch 22/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0616 - loss: 0.0210 - val_accuracy: 0.0786 - val_loss: 0.0211
# Epoch 23/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0554 - loss: 0.0205 - val_accuracy: 0.0643 - val_loss: 0.0204
# Epoch 24/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0478 - loss: 0.0209 - val_accuracy: 0.0643 - val_loss: 0.0202
# Epoch 25/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0570 - loss: 0.0206 - val_accuracy: 0.0571 - val_loss: 0.0207
# Epoch 26/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0399 - loss: 0.0206 - val_accuracy: 0.0786 - val_loss: 0.0203
# Epoch 27/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0460 - loss: 0.0214 - val_accuracy: 0.0643 - val_loss: 0.0202
# Epoch 28/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0453 - loss: 0.0205 - val_accuracy: 0.0643 - val_loss: 0.0204
# Epoch 29/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0552 - loss: 0.0206 - val_accuracy: 0.0643 - val_loss: 0.0201
# Epoch 30/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0681 - loss: 0.0207 - val_accuracy: 0.0643 - val_loss: 0.0200
# Tiempo de entrenamiento: 10.00 segundos
# Epoch 1/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.0161 - loss: 0.1238 - val_accuracy: 0.0214 - val_loss: 0.0606
# Epoch 2/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0043 - loss: 0.0627 - val_accuracy: 0.0071 - val_loss: 0.0501
# Epoch 3/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0119 - loss: 0.0525 - val_accuracy: 0.0214 - val_loss: 0.0436
# Epoch 4/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0402 - loss: 0.0456 - val_accuracy: 0.0357 - val_loss: 0.0381
# Epoch 5/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0329 - loss: 0.0402 - val_accuracy: 0.0357 - val_loss: 0.0332
# Epoch 6/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0398 - loss: 0.0357 - val_accuracy: 0.0357 - val_loss: 0.0296
# Epoch 7/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0411 - loss: 0.0311 - val_accuracy: 0.0500 - val_loss: 0.0266
# Epoch 8/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0581 - loss: 0.0282 - val_accuracy: 0.0357 - val_loss: 0.0241
# Epoch 9/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0507 - loss: 0.0268 - val_accuracy: 0.0286 - val_loss: 0.0238
# Epoch 10/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0566 - loss: 0.0252 - val_accuracy: 0.0500 - val_loss: 0.0223
# Epoch 11/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0516 - loss: 0.0239 - val_accuracy: 0.0500 - val_loss: 0.0216
# Epoch 12/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0812 - loss: 0.0230 - val_accuracy: 0.0571 - val_loss: 0.0210
# Epoch 13/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0523 - loss: 0.0222 - val_accuracy: 0.0500 - val_loss: 0.0210
# Epoch 14/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0704 - loss: 0.0218 - val_accuracy: 0.0500 - val_loss: 0.0209
# Epoch 15/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0519 - loss: 0.0224 - val_accuracy: 0.0500 - val_loss: 0.0207
# Epoch 16/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0642 - loss: 0.0218 - val_accuracy: 0.0643 - val_loss: 0.0208
# Epoch 17/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0569 - loss: 0.0216 - val_accuracy: 0.0714 - val_loss: 0.0202
# Epoch 18/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0681 - loss: 0.0213 - val_accuracy: 0.0429 - val_loss: 0.0202
# Epoch 19/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0643 - loss: 0.0214 - val_accuracy: 0.0643 - val_loss: 0.0208
# Epoch 20/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0481 - loss: 0.0215 - val_accuracy: 0.0643 - val_loss: 0.0202
# Epoch 21/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0665 - loss: 0.0211 - val_accuracy: 0.0500 - val_loss: 0.0202
# Epoch 22/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0359 - loss: 0.0211 - val_accuracy: 0.0429 - val_loss: 0.0205
# Epoch 23/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0412 - loss: 0.0215 - val_accuracy: 0.0286 - val_loss: 0.0204
# Epoch 24/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0260 - loss: 0.0213 - val_accuracy: 0.0357 - val_loss: 0.0201
# Epoch 25/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0591 - loss: 0.0209 - val_accuracy: 0.0429 - val_loss: 0.0206
# Epoch 26/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0564 - loss: 0.0209 - val_accuracy: 0.0357 - val_loss: 0.0200
# Epoch 27/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0391 - loss: 0.0205 - val_accuracy: 0.0500 - val_loss: 0.0201
# Epoch 28/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0621 - loss: 0.0206 - val_accuracy: 0.0214 - val_loss: 0.0200
# Epoch 29/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0456 - loss: 0.0204 - val_accuracy: 0.0500 - val_loss: 0.0204
# Epoch 30/30
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1014 - loss: 0.0209 - val_accuracy: 0.0571 - val_loss: 0.0201

# %% [markdown]
# # Rendimiento del Modelo

# %%
fig, axs = plt.subplots(nrows=1, ncols=2)
fig.set_size_inches(15, 6)
axs[0].plot(history1.history['loss'], label='Training Loss')
axs[0].plot(history1.history['val_loss'], label='Validation Loss')
axs[0].set_title('Training and Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[1].plot(history1.history['accuracy'], label='Accuracy')
axs[1].plot(history1.history['val_accuracy'], label='Val_Accuracy')
axs[1].set_title('Training and Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Predecir

# %%
psd_pred_scaled = model1.predict(X_scaled)
psd_pred = scalerPsd.inverse_transform(psd_pred_scaled)
print(psd_pred.shape)
plt.figure(figsize=(12, 6))
plt.semilogy(f, psd_pred[50], color='b', label='Prediction')
plt.semilogy(f, Psd_real[50], color='r', label='Real')
plt.xlabel('Frequency [Hz]')
plt.ylabel('PSD')
plt.title('Prediction vs Real PSD')
plt.legend()
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# (1000, 150)

# %%
np.random.seed(0)

def reconstruir_senal(f, psd, t):

    # Convertir la PSD en la magnitud del espectro de frecuencia
    magnitud = np.sqrt(psd)

    # Crear un espectro complejo con magnitud y fase aleatoria
    
    fase_aleatoria = np.exp(1j * np.random.uniform(0, 2 * np.pi, len(f)))
    espectro = magnitud * fase_aleatoria

    # Duplicar el espectro para considerar las frecuencias negativas
    espectro_completo = np.concatenate([espectro, np.conj(espectro[::-1])])

    # Realizar la IFFT para obtener la señaligena en el dominio temporal
    senal = np.fft.ifft(espectro_completo)

    # Asegurar que la señaligena resultante sea real
    senal_real = np.real(senal)

    # Shift the reconstructed signal to avoid loss in the middle
    senal_real = np.roll(senal_real, len(senal_real) // 2)

    return senal_real[:len(t)]


rec_X_real = np.zeros((M,300))
rec_X_pred = np.zeros((M,300))

for i in range(psd_pred.shape[0]):
    rec_pred = reconstruir_senal(f, psd_pred[i], t)
    rec_real = reconstruir_senal(f, Psd_real[i], t)
    rec_X_real[i] = rec_real
    rec_X_pred[i] = rec_pred

t_rec = t[:300]

rec_X_real = np.mean(rec_X_real, axis=0)
rec_X_pred = np.mean(rec_X_pred, axis=0)

plt.figure(figsize=(12,6))
plt.plot(t_rec, rec_X_real, label='real')
plt.plot(t_rec, rec_X_pred, label='pred')
plt.legend()
plt.show()

# %% [markdown]
# # Umbral adaptativo

# %%
def harmonics(f, psd):

    noise_level = noise_level = np.percentile(psd, 10)  # Usa el percentil 10 como estimación del ruido
    k = 0.0005
    thresholding = noise_level + k
    peaks, _ = sig.find_peaks(psd, height=thresholding, distance=1)
    peaks_filtered = peaks[psd[peaks] > thresholding] #filtrar picos
    harm_f = f[peaks_filtered]
    harm_psd = psd[peaks_filtered]


    return thresholding, harm_f, harm_psd


thres, harm_f, harm_psd = harmonics(f, psd_pred[100])

plt.figure(figsize=(12,6))
plt.semilogy(f, psd_pred[100])
plt.semilogy(f, np.full(len(f), thres))
plt.scatter(harm_f, harm_psd, c='r')

plt.show()

# %% [markdown]
# # KDE Kernel density estimation
#
# - Hallar el histograma de cada uno de los harmónicos.
# - Hacerle KDE para una función limpia gaussiana

# %%
def kde_harmonics(n_harm, f, Psd_m):
    M = Psd_m.shape[0]
    harmonics_vector = np.zeros((M, n_harm))

    for i in range(M):
        thres, harm_f, harm_psd = harmonics(f, Psd_m[i])
        harmonics_vector[i] = harm_psd
    
    for i in range(n_harm):

        harmonic = harmonics_vector[:,i]
        kde = stats.gaussian_kde(harmonic)
        x = np.linspace(np.min(harmonic), np.max(harmonic), 1000)
        pdf = kde(x)
        plt.figure(figsize=(12, 6))
        plt.hist(harmonic, bins=100, density=True, alpha=0.6, color='b', label='Histogram')
        plt.plot(x, pdf, c='r', label='KDE PDF')
        
        plt.xlabel('Frequency (Hz)') 
        plt.ylabel('Density')
        plt.legend()
        plt.show()

kde_harmonics(3, f, psd_pred)

# %% [markdown]
# # Señal reconstruida mediante umbral

# %%
def signal_rec_thresholding(harm_f, harm_psd, t):
    psd_normalized = harm_psd/(harm_psd.max())
    psd_vector = np.sqrt(psd_normalized)

    #Reconstruir señal

    rec_signal = psd_vector[0]*np.cos(2*np.pi*harm_f[0]*t) - psd_vector[1]*np.sin(2*np.pi*harm_f[1]*t) + psd_vector[2]*np.cos(2*np.pi*harm_f[2]*t)

    return rec_signal


rec_signal = signal_rec_thresholding(harm_f, harm_psd, t)
plt.figure(figsize=(12,5))
plt.plot(t, real_signal(t,wo))
plt.plot(t, rec_signal)
plt.show()

# %%
def NN_evaluation(sigma, t, wo, fs, nperseg, window, nfft, fn, test_size, NN_type, epochs, N, M):
    mse_vector = np.zeros(len(sigma))
    mae_vector = np.zeros(len(sigma))

    for j in range(len(sigma)):

        X = matrix_data(t, wo, sigma[j], N, M)

        f, Psd_real = matrix_psd(X, fs, nperseg, window, nfft, fn, N, M)

        X_train, X_test, y_train, y_test, X_scaled, Psd_scaled, scalerX, scalerPsd= data_split_scaled(X, Psd_real, test_size)

        history1, model1 = NN_define(NN_type, X_train, y_train, epochs, N, fn)

        psd_pred_scaled = model1.predict(X_scaled)
        psd_pred = scalerPsd.inverse_transform(psd_pred_scaled)

        mse_per_signal = np.zeros(M)
        mae_per_signal = np.zeros(M)

        for k in range(M):
            mse_per_signal[k] = mean_squared_error(psd_pred[k], Psd_real[k])
            mae_per_signal[k] = mean_absolute_error(psd_pred[k], Psd_real[k])

        mse_vector[j] = np.mean(mse_per_signal)
        mae_vector[j] = np.mean(mae_per_signal)

    rmse_vector = np.sqrt(mse_vector)

    return mse_vector, mae_vector, rmse_vector


sigma = [0, 0.1, 0.2, 0.5, 1, 5, 10, 30]
mse_vector, mae_vector, rmse_vector = NN_evaluation(sigma, t, wo, fs, nperseg, 'blackmanharris', nfft, fn, 0.3, 1, 10, N, M)
# Out:
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.0015 - loss: 0.1327 - val_accuracy: 0.0071 - val_loss: 0.0584
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0066 - loss: 0.0628 - val_accuracy: 0.0000e+00 - val_loss: 0.0507
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0099 - loss: 0.0521 - val_accuracy: 0.0071 - val_loss: 0.0424
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0228 - loss: 0.0446 - val_accuracy: 0.0214 - val_loss: 0.0363
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0157 - loss: 0.0386 - val_accuracy: 0.0143 - val_loss: 0.0313
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0174 - loss: 0.0345 - val_accuracy: 0.0286 - val_loss: 0.0276
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0142 - loss: 0.0306 - val_accuracy: 0.0214 - val_loss: 0.0251
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0226 - loss: 0.0288 - val_accuracy: 0.0500 - val_loss: 0.0235
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0160 - loss: 0.0266 - val_accuracy: 0.0500 - val_loss: 0.0225
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0443 - loss: 0.0252 - val_accuracy: 0.0643 - val_loss: 0.0222
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 4.9716e-04 - loss: 0.1280 - val_accuracy: 0.0143 - val_loss: 0.0538
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0046 - loss: 0.0585 - val_accuracy: 0.0143 - val_loss: 0.0497
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0066 - loss: 0.0523 - val_accuracy: 0.0000e+00 - val_loss: 0.0455
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0091 - loss: 0.0470 - val_accuracy: 0.0000e+00 - val_loss: 0.0401
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0183 - loss: 0.0410 - val_accuracy: 0.0071 - val_loss: 0.0344
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0120 - loss: 0.0367 - val_accuracy: 0.0571 - val_loss: 0.0298
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0415 - loss: 0.0314 - val_accuracy: 0.0643 - val_loss: 0.0263
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0324 - loss: 0.0288 - val_accuracy: 0.0571 - val_loss: 0.0240
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0508 - loss: 0.0270 - val_accuracy: 0.0571 - val_loss: 0.0228
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0479 - loss: 0.0250 - val_accuracy: 0.0714 - val_loss: 0.0218
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0095 - loss: 0.1374 - val_accuracy: 0.0286 - val_loss: 0.0582
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0153 - loss: 0.0617 - val_accuracy: 0.0071 - val_loss: 0.0527
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0078 - loss: 0.0522 - val_accuracy: 0.0071 - val_loss: 0.0471
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0137 - loss: 0.0470 - val_accuracy: 0.0071 - val_loss: 0.0405
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0145 - loss: 0.0414 - val_accuracy: 0.0000e+00 - val_loss: 0.0352
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0119 - loss: 0.0360 - val_accuracy: 0.0000e+00 - val_loss: 0.0311
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0149 - loss: 0.0324 - val_accuracy: 0.0071 - val_loss: 0.0285
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0354 - loss: 0.0296 - val_accuracy: 0.0143 - val_loss: 0.0269
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0407 - loss: 0.0270 - val_accuracy: 0.0000e+00 - val_loss: 0.0251
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0657 - loss: 0.0261 - val_accuracy: 0.0786 - val_loss: 0.0242
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0050 - loss: 0.1387 - val_accuracy: 0.0571 - val_loss: 0.0427
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0200 - loss: 0.0497 - val_accuracy: 0.0357 - val_loss: 0.0391
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0212 - loss: 0.0429 - val_accuracy: 0.0214 - val_loss: 0.0354
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0451 - loss: 0.0387 - val_accuracy: 0.0286 - val_loss: 0.0316
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0600 - loss: 0.0348 - val_accuracy: 0.0714 - val_loss: 0.0286
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0913 - loss: 0.0322 - val_accuracy: 0.1214 - val_loss: 0.0263
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0648 - loss: 0.0290 - val_accuracy: 0.1000 - val_loss: 0.0240
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0693 - loss: 0.0278 - val_accuracy: 0.1643 - val_loss: 0.0225
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0883 - loss: 0.0257 - val_accuracy: 0.1714 - val_loss: 0.0213
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1273 - loss: 0.0241 - val_accuracy: 0.1786 - val_loss: 0.0206
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.0231 - loss: 0.1228 - val_accuracy: 0.0143 - val_loss: 0.0422
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0107 - loss: 0.0459 - val_accuracy: 0.0214 - val_loss: 0.0398
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0118 - loss: 0.0410 - val_accuracy: 0.0214 - val_loss: 0.0363
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0105 - loss: 0.0369 - val_accuracy: 0.0214 - val_loss: 0.0326
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0247 - loss: 0.0329 - val_accuracy: 0.0214 - val_loss: 0.0294
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0111 - loss: 0.0308 - val_accuracy: 0.0214 - val_loss: 0.0271
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0155 - loss: 0.0277 - val_accuracy: 0.0214 - val_loss: 0.0249
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0203 - loss: 0.0255 - val_accuracy: 0.0214 - val_loss: 0.0234
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0343 - loss: 0.0244 - val_accuracy: 0.0214 - val_loss: 0.0224
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0377 - loss: 0.0232 - val_accuracy: 0.0214 - val_loss: 0.0215
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0028 - loss: 0.0899 - val_accuracy: 0.0071 - val_loss: 0.0363
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0066 - loss: 0.0400 - val_accuracy: 0.0000e+00 - val_loss: 0.0342
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0055 - loss: 0.0353 - val_accuracy: 0.0000e+00 - val_loss: 0.0324
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0040 - loss: 0.0339 - val_accuracy: 0.0000e+00 - val_loss: 0.0306
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0082 - loss: 0.0311 - val_accuracy: 0.0000e+00 - val_loss: 0.0283
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0074 - loss: 0.0298 - val_accuracy: 0.0071 - val_loss: 0.0262
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0184 - loss: 0.0273 - val_accuracy: 0.0071 - val_loss: 0.0243
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0287 - loss: 0.0255 - val_accuracy: 0.0071 - val_loss: 0.0228
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0286 - loss: 0.0235 - val_accuracy: 0.0143 - val_loss: 0.0215
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0317 - loss: 0.0223 - val_accuracy: 0.0143 - val_loss: 0.0207
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.0100 - loss: 0.1516 - val_accuracy: 0.0000e+00 - val_loss: 0.0389
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0015 - loss: 0.0459 - val_accuracy: 0.0143 - val_loss: 0.0356
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0122 - loss: 0.0384 - val_accuracy: 0.0143 - val_loss: 0.0337
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0052 - loss: 0.0340 - val_accuracy: 0.0143 - val_loss: 0.0323
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0077 - loss: 0.0325 - val_accuracy: 0.0143 - val_loss: 0.0304
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0091 - loss: 0.0308 - val_accuracy: 0.0071 - val_loss: 0.0285
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0126 - loss: 0.0288 - val_accuracy: 0.0000e+00 - val_loss: 0.0267
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0066 - loss: 0.0272 - val_accuracy: 0.0071 - val_loss: 0.0252
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0134 - loss: 0.0252 - val_accuracy: 0.0071 - val_loss: 0.0240
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0103 - loss: 0.0237 - val_accuracy: 0.0071 - val_loss: 0.0230
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
plt.figure(figsize=(12,6))
plt.semilogx(sigma, mse_vector, c='r', label='MSE')
plt.semilogx(sigma, mae_vector, c='g', label='MAE')
plt.semilogx(sigma, rmse_vector, c='b', label='RMSE')
plt.xlabel('Varianza')
plt.legend()
plt.show()
